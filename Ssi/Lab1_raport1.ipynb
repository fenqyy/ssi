# %%
import K_srednia

# Uruchomienie algorytmu
srodki, grupy, checkpoints_data = K_srednia.k_srednia(3, 10, 'euk')

# Analiza i wizualizacja po 4 i 10 iteracjach
for iteracja, (srodki_iter, grupy_iter) in checkpoints_data.items():
    print(f"\nAnaliza po {iteracja} iteracjach:")
    raport = K_srednia.analiza_grup(grupy_iter)
    for r in raport:
        print(r)
    K_srednia.rysuj_wykres(srodki_iter, grupy_iter, "K-średnie", iteracja)
# Out:
# Analiza po 4 iteracjach:
# {'grupa': 1, 'liczba_prob': 35, 'x1_min': -0.0824, 'x1_max': 1.3375, 'x2_min': -0.6311, 'x2_max': 1.9473}
# {'grupa': 2, 'liczba_prob': 34, 'x1_min': -1.4969, 'x1_max': 1.1371, 'x2_min': -1.5564, 'x2_max': -0.7615}
# {'grupa': 3, 'liczba_prob': 32, 'x1_min': -1.779, 'x1_max': -0.2074, 'x2_min': -0.6608, 'x2_max': 1.9929}
# Analiza po 10 iteracjach:
# {'grupa': 1, 'liczba_prob': 37, 'x1_min': -0.0824, 'x1_max': 1.3375, 'x2_min': -0.8127, 'x2_max': 1.0724}
# {'grupa': 2, 'liczba_prob': 33, 'x1_min': -1.5441, 'x1_max': 0.9918, 'x2_min': -1.5564, 'x2_max': -0.6479}
# {'grupa': 3, 'liczba_prob': 31, 'x1_min': -1.779, 'x1_max': 0.0322, 'x2_min': -0.4747, 'x2_max': 1.9929}

# %%
# Uruchomienie algorytmu
srodki1, grupy1, checkpoints_data1 = K_srednia.k_mediana(3, 10, 'euk')

# Analiza i wizualizacja po 4 i 10 iteracjach
for iteracja, (srodki_iter, grupy_iter) in checkpoints_data1.items():
    print(f"\nAnaliza po {iteracja} iteracjach:")
    raport = K_srednia.analiza_grup(grupy_iter)
    for r in raport:
        print(r)
    K_srednia.rysuj_wykres(srodki_iter, grupy_iter, "K-mediany", iteracja)
# Out:
# Analiza po 4 iteracjach:
# {'grupa': 1, 'liczba_prob': 32, 'x1_min': -1.5488, 'x1_max': 0.9301, 'x2_min': -1.5564, 'x2_max': -0.4747}
# {'grupa': 2, 'liczba_prob': 30, 'x1_min': -1.779, 'x1_max': 0.0322, 'x2_min': -0.3264, 'x2_max': 1.9929}
# {'grupa': 3, 'liczba_prob': 39, 'x1_min': -0.0824, 'x1_max': 1.3375, 'x2_min': -1.0194, 'x2_max': 1.0724}
# Analiza po 10 iteracjach:
# {'grupa': 1, 'liczba_prob': 34, 'x1_min': -1.5488, 'x1_max': 0.9918, 'x2_min': -1.5564, 'x2_max': -0.4747}
# {'grupa': 2, 'liczba_prob': 30, 'x1_min': -1.779, 'x1_max': 0.0322, 'x2_min': -0.3264, 'x2_max': 1.9929}
# {'grupa': 3, 'liczba_prob': 37, 'x1_min': -0.0824, 'x1_max': 1.3375, 'x2_min': -0.8127, 'x2_max': 1.0724}
