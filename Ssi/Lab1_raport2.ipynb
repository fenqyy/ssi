# %%
import K_srednia

# Uruchomienie algorytmu
srodki, grupy, checkpoints_data = K_srednia.k_srednia(4, 10, 'man')

# Analiza i wizualizacja po 4 i 10 iteracjach
for iteracja, (srodki_iter, grupy_iter) in checkpoints_data.items():
    print(f"\nAnaliza po {iteracja} iteracjach:")
    raport = K_srednia.analiza_grup(grupy_iter)
    for r in raport:
        print(r)
    K_srednia.rysuj_wykres(srodki_iter, grupy_iter, "K-średnie", iteracja)
# Out:
# Analiza po 4 iteracjach:
# {'grupa': 1, 'liczba_prob': 19, 'x1_min': 0.343, 'x1_max': 0.9301, 'x2_min': -1.3957, 'x2_max': 1.0724}
# {'grupa': 2, 'liczba_prob': 23, 'x1_min': -0.6295, 'x1_max': 0.2717, 'x2_min': -1.5564, 'x2_max': 1.9929}
# {'grupa': 3, 'liczba_prob': 22, 'x1_min': 0.9918, 'x1_max': 1.3375, 'x2_min': -1.0194, 'x2_max': 0.6502}
# {'grupa': 4, 'liczba_prob': 37, 'x1_min': -1.779, 'x1_max': -0.8084, 'x2_min': -1.3649, 'x2_max': 1.8031}
# Analiza po 10 iteracjach:
# {'grupa': 1, 'liczba_prob': 20, 'x1_min': 0.0913, 'x1_max': 0.803, 'x2_min': -1.4508, 'x2_max': 1.0724}
# {'grupa': 2, 'liczba_prob': 21, 'x1_min': -0.8967, 'x1_max': 0.0476, 'x2_min': -1.5564, 'x2_max': 1.9929}
# {'grupa': 3, 'liczba_prob': 28, 'x1_min': 0.8318, 'x1_max': 1.3375, 'x2_min': -1.1675, 'x2_max': 0.8573}
# {'grupa': 4, 'liczba_prob': 32, 'x1_min': -1.779, 'x1_max': -0.952, 'x2_min': -1.3021, 'x2_max': 1.6521}
